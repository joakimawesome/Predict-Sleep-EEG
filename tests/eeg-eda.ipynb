# %%
import os
import mne

# %%
main_dir = os.path.dirname(os.getcwd())
file_EEG = os.listdir(main_dir + r'/data/EEG')
file_vhdr = [f for f in file_EEG if f.split('.')[-1] == 'vhdr']

idx = 0 # the experiment number
path_vhdr = "../data/EEG/" + file_vhdr[idx]

raw = mne.io.read_raw_brainvision(path_vhdr)
raw
# Out:
# Extracting parameters from ../data/EEG/suj11_l5nap_day1.vhdr...
# Setting channel info structure...
# <RawBrainVision | suj11_l5nap_day1.eeg, 64 x 1858750 (1858.7 s), ~68 kB, data not loaded>

# %%
raw.plot(duration=5, n_channels=64);
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
signal = raw.copy()
signal.load_data()

# signal.plot(duration=10, start=600, n_channels=2);
# signal.plot(duration=10, start=600, n_channels=2, highpass=0.3, lowpass=3.5, verbose=False);
# signal.plot(duration=10, start=600, n_channels=2, highpass=1.0, lowpass=16.0, verbose=False);
# signal.plot(duration=10, start=600, n_channels=2, highpass=1.0, lowpass=35.0, verbose=False);
# signal.plot(duration=10, start=600, n_channels=2, highpass=1.0, lowpass=70, verbose=False);

# signal.plot(duration=10, start=1200, n_channels=2);
# signal.plot(duration=10, start=1200, n_channels=2, highpass=0.3, lowpass=3.5, verbose=False);
# signal.plot(duration=10, start=1200, n_channels=2, highpass=1.0, lowpass=16.0, verbose=False);
# signal.plot(duration=10, start=1200, n_channels=2, highpass=1.0, lowpass=35.0, verbose=False);
# signal.plot(duration=10, start=1200, n_channels=2, highpass=1.0, lowpass=70, verbose=False);

signal.plot(duration=10, start=1740, n_channels=2);
signal.plot(duration=10, start=1740, n_channels=2, highpass=0.3, lowpass=3.5, verbose=False);
signal.plot(duration=10, start=1740, n_channels=2, highpass=1.0, lowpass=16.0, verbose=False);
signal.plot(duration=10, start=1740, n_channels=2, highpass=1.0, lowpass=35.0, verbose=False);
signal.plot(duration=10, start=1740, n_channels=2, highpass=1.0, lowpass=70, verbose=False);
# Out:
# Reading 0 ... 1858749  =      0.000 ...  1858.749 secs...
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
signal.plot(duration=10, start=1740, n_channels=2, highpass=11.0, lowpass=16.0, verbose=False);
# Out:
# <MNEBrowseFigure size 576x576 with 4 Axes>
